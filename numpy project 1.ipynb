# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

img=Image.open(r"C:\Users\Sanya\Desktop\summer training\shortcake.jpg")
img=np.array(img)
img[:,:,0]=np.clip(img[:,:,0]+100,100,255)
plt.imshow(img)
plt.axis("off")
plt.show()
